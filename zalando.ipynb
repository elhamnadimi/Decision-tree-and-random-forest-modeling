# %% [markdown]
# # Task description
# ## Background
# One application of Machine Learning in an eCommerce setting is to find the best products for a specific search query. Even the best algorithms, however, are not guaranteed to be optimal, in the sense that occasionaly some products chosen by the algorithm for a query may in fact be irrelevant. This may not be good for the customer experience, since the customer may wonder why irrelevant products are shown in the result page. Hence it is important to identify these products and not show them to the customers.
# ## Goal
# The goal of this exercise is to create an algorithm that identifies these irrelevant results based on product attributes. We provide you with a small dataset containing the products returned by a black-box ML algorithm for a set of queries, together with a label describing if a product is irrelevant to the respective query. The goal of the assignment is to write an algorithm that detects these irrelevant products based on the product attributes present in the data. This algorithm could then be used to remove irrelevant products from other queries, hence improving the search experience of our customers.
# ## Deliverables
# The result of the exercise should be this notebook containing the following sections:
# * Load the data
# * Short data analysis
#   * Description of the data (number of queries, number of products per query, number of available attributes,...)
#   * Plot of a histogram showing the number of queries with varying percentage of irrelevant products in the result set
# * Algorithm implementation
# * Algorithm evaluation
#   * Dictionary named "query_results" containing accuracy, precision, recall and F1-score for each query as {'query1':{'accuracy':value,'precision':value,...},'query2':{...}}
#   * Dictionary named "results" containing mean accuracy, precision, recall and F1-score over all queries as {'accuracy':value, 'precision':value,...}

# %% [markdown]
# # Load Data

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #I
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn import tree
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier

# %%
#Load the dataset.
df = pd.read_csv ("../input/nllllpppp/data.csv")
df[0:5]
# Out:
#                    query price_cluster commodity_group product_group  \
# 0  t-shirt dolce gabbana           low      4-2-B-01-1          shoe
# 1  t-shirt dolce gabbana           low         1-2-G-3          shoe
# 2  t-shirt dolce gabbana           low         1-2-G-4          shoe
# 3  t-shirt dolce gabbana          high         1-2-G-3          shoe
# 4  t-shirt dolce gabbana           low         1-2-C-1          shoe
#
#          silhouette               brand    color            upper_material  \
# 0  backless_slipper  adidas Performance  schwarz                Kunststoff
# 1  backless_slipper               Guess  schwarz                Kunststoff
# 2  backless_slipper      Tommy Hilfiger      rot          Leder und Textil
# 3  backless_slipper            MOSCHINO  schwarz  hochwertiges Lederimitat
# 4          low_shoe            Pier One     gelb                    Textil
#
#      pattern  label
# 0      print      1
# 1  unifarben      1
# 2  gestreift      1
# 3  unifarben      1
# 4  unifarben      1

# %% [markdown]
# # Data analysis

# %%
#Distribution of label.
sns.countplot(df['label'],label="Count",alpha=0.9)
plt.xticks(rotation=60)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Number of queries,

# %%
print('The shape of our features is:', df.shape)
df=df.replace(np.nan,0)
# Out:
# The shape of our features is: (2160, 10)

# %% [markdown]
# **Number of products per query**

# %%
df_prod_query=df.groupby(['query',"product_group"],as_index=False).agg({'label':pd.Series.count})
df_prod_query
# Out:
#                        query product_group  label
# 0              aigle stiefel      clothing      5
# 1              aigle stiefel          shoe     65
# 2              aigle stiefel     underwear     10
# 3        asics gel venture 8          shoe     80
# 4            baggy trackpant      clothing     80
# ..                       ...           ...    ...
# 56         tshirt kleid kurz   accessoires      3
# 57         tshirt kleid kurz        beauty      2
# 58         tshirt kleid kurz      clothing     75
# 59  wanderschuhe lowa kinder     nightwear      5
# 60  wanderschuhe lowa kinder          shoe     75
#
# [61 rows x 3 columns]

# %% [markdown]
# Plot of a histogram showing the number of queries with varying percentage of irrelevant products in the result set

# %%
plt.figure(figsize=(15,8))
#data=df.groupby(['query'],as_index=False).agg({'label':pd.Series.sum})
data = df.groupby('query')['label'].sum().reset_index()
data['Percentage'] = 100 * data['label']  / data['label'].sum()
print(data)
ax = data.plot.bar(x='query',y='Percentage',color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.title("queries with percentage of irrelevant products ")

ax.yaxis.set_major_formatter(mtick.PercentFormatter())
# Out:
#                              query  label  Percentage
# 0                    aigle stiefel     13    3.266332
# 1              asics gel venture 8     11    2.763819
# 2                  baggy trackpant     12    3.015075
# 3                     barney jacke      4    1.005025
# 4        british knights master lo      4    1.005025
# 5   california west coast pullover     17    4.271357
# 6         carhartt wip windbreaker      5    1.256281
# 7                     chelsea wide      4    1.005025
# 8            collegejacken vintage     13    3.266332
# 9             converse schuhe herz      8    2.010050
# 10                      damenchino      2    0.502513
# 11                  hairband sport     38    9.547739
# 12              halskragenpullover     29    7.286432
# 13                   jogging cargo     12    3.015075
# 14                joggpants kinder     26    6.532663
# 15               jumpsuits kariert     30    7.537688
# 16            lacoste taschen sale      5    1.256281
# 17    naketano damen kapuzenjacken      4    1.005025
# 18           nike pullover vintage      5    1.256281
# 19               regenjacke joules     38    9.547739
# 20      save the duck mäntel damen      7    1.758794
# 21            selected femme boots      7    1.758794
# 22             sonnenbrille chanel     23    5.778894
# 23         stiefeletten pepe jeans     11    2.763819
# 24           t-shirt dolce gabbana     39    9.798995
# 25               tshirt kleid kurz     28    7.035176
# 26        wanderschuhe lowa kinder      3    0.753769

# %%
# check missing values in variables
df.isnull().sum()
# Out:
# query              0
# price_cluster      0
# commodity_group    0
# product_group      0
# silhouette         0
# brand              0
# color              0
# upper_material     0
# pattern            0
# label              0
# dtype: int64

# %%
print(df['query'].unique())
print(df['price_cluster'].unique())
#print(df['commodity_group'].unique())
print(df['product_group'].unique())
print(df['silhouette'].unique())
print(df['brand'].unique())
print(df['upper_material'].unique())
print(df['pattern'].unique())
# Out:
# ['t-shirt dolce gabbana' 'selected femme boots' 'hairband sport'
#  'halskragenpullover' 'stiefeletten pepe jeans' 'barney jacke'
#  'chelsea wide' 'california west coast pullover'
#  'carhartt wip windbreaker' 'save the duck mäntel damen'
#  'collegejacken vintage' 'converse schuhe herz'
#  'naketano damen kapuzenjacken' 'sonnenbrille chanel'
#  'british knights master lo' 'aigle stiefel' 'asics gel venture 8'
#  'tshirt kleid kurz' 'jumpsuits kariert' 'damenchino' 'joggpants kinder'
#  'baggy trackpant' 'wanderschuhe lowa kinder' 'regenjacke joules'
#  'nike pullover vintage' 'lacoste taschen sale' 'jogging cargo']
# ['low' 'high' 'entry' 'medium' 'undefined']
# ['shoe' 'clothing' 'accessoires' 'equipment' 'beauty' 'other' 'underwear'
#  'beach_wear' 'nightwear']
# ['backless_slipper' 'low_shoe' 'sandals' 't_shirt_top' 'trouser' 'belt'
#  'ankle_boots' 'coat' 'boots' 'bag' 'sneaker' 'fitness' 'jewellery'
#  'beauty_equipment' 'other_equipment' 'gloves' 'headgear'
#  'other_accessoires' 'scarf' 'pullover' 'cardigan' 'pumps' 'shirt'
#  'jacket' 'system' 'dress' 'bra' 'wallet' 'skirt' 'glasses' 'beach_shirt'
#  'one_piece_suit' 'stocking' 'face_cosmetic' 'one_piece_beachwear'
#  'nightwear_combination' 'combination_clothing' 'backpack' 'skincare'
#  'nail']
# ['adidas Performance' 'Guess' 'Tommy Hilfiger' 'MOSCHINO' 'Pier One'
#  'Quiksilver' 'Emporio Armani' 'Versace Jeans Couture' 'Diesel'
#  'PRIMA MODA' 'Brave Soul' 'Calvin Klein Jeans' 'Converse' 'Reef'
#  'Glorious Gangsta' 'Polo Ralph Lauren' "Levi's®" 'adidas Originals'
#  'Armani Exchange' 'INDICODE JEANS' 'Just Cavalli' 'Jordan' 'Tommy Jeans'
#  'KARL LAGERFELD' 'TOM TAILOR' 'Blackstone' 'Zign' 'ALDO' 'Pavement'
#  'Shoe The Bear' 'Vagabond' 'KIOMI' 'Bianco' 'Gabor' 'Peter Kaiser'
#  'Selected Femme Tall' 'Finn Flare' 'Jonak' 'Unisa' 'Tamaris' 'Sixtyseven'
#  'Darkwood' 'Oxitaly' 'Paul Green' 'Bruno Premi' 'Ekonika'
#  'Pedro Miralles' 'Högl' 'Paco Gil' 'Topshop' 'Legero' 'Pretty Ballerinas'
#  'Pieces' 'Manfield' 'Selected Femme' 'Luca Grossi' 'Scapa' 'Cream'
#  'Caprice' 'Abro' 'Bianca Di' 'ara' 'Hash#TAG Sustainable' 'Pajar'
#  'Head over Heels by Dune' 'Geox' 'MAHONY' 'Envii' 'YAS' 'Casall' 'Craft'
#  'ONLY' 'ZOË AYLA' 'Nike Performance' 'Ziener' 'Nike Golf' 'Under Armour'
#  'Popband' 'Hershesons' 'Invisibobble' 'Buff' 'Esprit' 'Yogasearcher'
#  "Marc O'Polo" 'ASICS' 'Giesswein' 'Superdry' 'Kari Traa' 'Lacoste Sport'
#  'LTB' 'Jack & Jones' 'Club Monaco' 'camel active' 'Bertoni'
#  'Selected Homme' 'Goosecraft' 's.Oliver' 'Solid' 'DNR Jackets' 'BOSS'
#  'Petrol Industries' 'Key Largo' 'JOOP! Jeans' 'JP1880' 'Serge Pariente'
#  'HUGO' 'Strellson' 'Daniel Hechter' 'JCC' 'Replay' 'Woodbird'
#  'TOM TAILOR DENIM' 'Oakwood' 'Rusty Neal' 'Lindbergh' 'COCO'
#  'Cipo & Baxx' 'Cross Jeans' 'Mavi' 'J.LINDEBERG' 'Junk De Luxe'
#  'Redefined Rebel' 'Lee' 'Be Edgy' 'Matinique' 'Filippa K' 'New Look'
#  'Mustang' 'Sand Copenhagen' 'MJUS' 'Felmini' 'Royal RepubliQ' 'Bullboxer'
#  'Toral' 'San Marina' 'LOIS Jeans' 'Musse & Cloud' 'Billi Bi'
#  'Pinto Di Blu' 'Vero Moda' 'J.CREW' 'CAFèNOIR' "Ca'Shott" 'Mother'
#  'Clarks' 'InWear' 'Kanna' 'Pepe Jeans' 'Roxy' 'Gardenia' 'Gestuz'
#  'Carvela Comfort' 'Bronx' 'Another-Label' 'Kings Of Indigo' 'PoiLei'
#  'MICHAEL Michael Kors' 'Brenda Zaro' 'Evita' 'Next' 'mbyM' 'Tigha'
#  'Gipsy' 'Stradivarius' 'Royal Denim Division by Jack & Jones' 'G-Star'
#  'Desigual' 'Freaky Nation' 'Mango' 'AllSaints' 'Champion Reverse Weave'
#  'Anna Field' 'Clarks Originals' 'Pikolinos' 'Simply Be' 'mtng'
#  'Birkenstock' 'ILC' 'Toral Wide Fit' 'Rieker' 'Dorothy Perkins' 'COX'
#  'Steven New York' 'Anna Field Wide Fit' 'Crickit'
#  'Dorothy Perkins Wide Fit' 'Think!' 'Divine Factory' 'Apple of Eden'
#  'Felmini Wide Fit' 'RE:DESIGNED' 'Marco Tozzi' 'Even&Odd Wide Fit'
#  'Anna Field Curvy' 'Faith Wide Fit' 'Evans' 'Lloyd' 'Jana'
#  'Office Wide Fit' 'Barbour' 'Rubi Shoes by Cotton On' 'A.S.98'
#  'PULL&BEAR' 'Even&Odd' 'Gina Tricot' 'Missguided' 'Noisy May' 'Weekday'
#  'Urban Classics' 'DeFacto' 'Wrangler' 'Even&Odd Petite' 'Trendyol'
#  'Pimkie' 'Fila' 'America Today' 'Missguided Petite' 'Bershka' 'Monki'
#  'Nly by Nelly' 'Missguided Tall' 'Nike Sportswear' 'American Eagle'
#  'Timberland' 'Carhartt WIP' 'Napapijri' 'Ellesse' 'Columbia' 'Dickies'
#  'edc by Esprit' 'The North Face' 'Brandit' 'Vans' 'Schott'
#  'Obey Clothing' 'Starter' 'Helly Hansen' 'Save the duck' 'No.1 Como'
#  'Frieda & Freddies' 'Blauer' 'Derbe' 'Y by Nordisk' 'Saint Tropez'
#  'Rossignol' 'Didriksons' 'UGG' 'JOTT' 'Lauren Ralph Lauren'
#  'Bogner Fire + Ice' '7 for all mankind' 'Peuterey' 'Canadian Classics'
#  'DRYKORN' 'Mos Mosh' 'Patrizia Pepe' 'GANT' 'Colmar Originals' 'GAP'
#  'Mads Nørgaard' 'Mammut' 'Duvetica' 'Bomboogie' 'Calvin Klein'
#  'Liu Jo Jeans' 'New Era' 'Von Dutch' 'Jaded London' 'Zizzi'
#  'Oliver Bonas' 'Yoek' 'Fanatics' 'Ed Hardy' 'Noisy May Curve' 'DORINA'
#  'STAPLE PIGEON' 'Karl Kani' 'Kickers Classics' 'Night Addict'
#  'Lyle & Scott' 'b.young' 'SEXFORSAINTS' 'Lacoste LIVE' 'Mennace'
#  'ONLY Carmakoma' 'Ziq and Yoni' 'Betty Barclay' 'FUBU' 'myMo at night'
#  'BDG Urban Outfitters' 'Violeta by Mango' 'Studio Untold'
#  'The Ragged Priest' 'Queen Kerosin' 'Eight 2 Nine' 'Lindex'
#  'Liebeskind Berlin' 'Fjällräven' 'U.S. Polo Assn.' 'New Balance'
#  'Desires' 'alife & kickin' 'myMo' 'Naketano' 'DreiMaster' 'Hollister Co.'
#  'Ragwear Plus' 'Mazine' 'Ragwear' 'CODE | ZERO' 'Josef Seibel'
#  'Freequent' 'OXXO' 'Oxmo' 'Lakeville Mountain' 'Cecil' 'Blendshe'
#  'Q/S designed by' 'Sunnylife' 'Versace' 'BOSS Kidswear' 'Ray-Ban'
#  'VOGUE Eyewear' 'Stella McCartney' 'Zoobug' 'Wheat' 'Molo' 'Benetton'
#  'Lili Gaufrette' 'Puma' 'The Marc Jacobs' 'British Knights' 'Cotton On'
#  'CLOSURE London' 'Bugatti' 'Steve Madden' 'YOURTURN'
#  'Burton Menswear London' 'Dockers by Gerli' 'River Island'
#  'Madden by Steve Madden' 'Topman' 'FALKE' 'Viking' 'Keen' 'Tretorn'
#  'Lowa' 'Travelin' 'Scarpa' 'Sorel' 'Mols' 'Haglöfs' 'Dunlop' 'Moma'
#  'MADSea' 'Camper' 'Dolomite' 'Intimissimi' 'Panama Jack' 'Blundstone'
#  'Hunter ORIGINAL' 'Floris van Bommel' 'Shepherd' 'Bogs' 'Gore Wear'
#  'Salomon' 'Saucony' 'ECCO' 'Merrell' 'Caterpillar' 'Mother of Pearl'
#  'NA-KD' 'RIANI' 'Vivetta' 'JDY' 'Live Unlimited London' 'Reebok Classic'
#  'MY TRUE ME TOM TAILOR' 'Trueprodigy' 'Estée Lauder' 'Lounge Nine'
#  'By Malene Birger' 'Casa Amuk' 'Brooks Brothers' 'Minimum' 'Moves' 'LMTD'
#  'Object' 'Lacoste' "L'Oréal Paris" 'Molly Bracken' 'Ana Alcazar' 'zero'
#  'RISA' 'LASCANA' 'Underprotection' 'Ética' 'HotSquash' 'RVCA' 'Part Two'
#  'Never Fully Dressed' 'Pieces Petite' 'Glamorous Petite'
#  'Esprit Collection' 'sacha' 'Vero Moda Petite' 'Banana Republic'
#  'Tata Italia' 'Siren' 'Fashion Union' 'U Collection by Forever Unique'
#  'CIA MARÍTIMA' 'Pons Quintana' 'Selected Femme Petite' 'PETER HAHN'
#  'Karen by Simonsen' 'Scotch & Soda' 'Fransa' 'Regatta' 'Dare 2B'
#  'Zimtstern' 's.Oliver BLACK LABEL' 'Eddie Bauer' 'Vila' 'comma' 'Protest'
#  'ONLY Tall' 'Le Temps Des Cerises' 'mine to five TOM TAILOR' 'Kaffe'
#  'Cache Cache' 'Cero & Etage' 'Salewa' 'Betty & Co' 'Fritzi aus Preußen'
#  'Jack Wolfskin' 'Vaude' 'Soccx' 'Street One' 'Vero Moda Tall' 'MAC'
#  'True Religion' 'Soyaconcept' 'Cartoon' 'Gap Tall' 'ONLY Petite'
#  'MAC Jeans' 'Moss Copenhagen' 'YAS Tall' 'ONLY Play' 'ONLY PLAY Petite'
#  'Forever New' 'Opus' 'Homeboy' 'Han Kjøbenhavn' 'NU-IN' 'Native Youth'
#  'Henrik Vibskov' 'Reebok' 'URBN SAINT' 'Kaotiko' 'Blend'
#  'Jack´s Sportswear' 'HUF' 'CMP' 'Kastinger' 'TrollKids' 'Sanetta'
#  'Schiesser' 'Meindl' 'Hi-Tec' 'Playshoes' 'Bisgaard' 'Aigle' 'CeLaVi'
#  'Bergstein' 'Hummel' 'LEGO Wear' 'ZIGZAG' 'Boboli' 'Steiff Collection'
#  'Petit Bateau' 'Kavat' 'Reima' 'Name it' 'Armor lux' 'Crocs'
#  'Criminal Damage' 'Champion' 'Nike SB' 'Mister Tee' 'Kids ONLY' 'Grunt'
#  'Bogner' 'JOOP!' 'Max Mara Leisure' 'GINA LAURA' 'Sixth June' 'Elli'
#  'Résumé' 'COMME DEUX' 'Nails Inc' 'OPI' 'Icepeak' 'one more story'
#  'Essie' 'Culture' 'J Brand']
# ['Kunststoff' 'Leder und Textil' 'hochwertiges Lederimitat' 'Textil'
#  'undefined' 'Leder' 'Lederimitat/Textil' 'Polyester' 'Veloursleder'
#  'Nubuk' 'Kalbsleder' 'Wildleder / Suede' 'Schafsleder'
#  'Leder und Lederimitat' 'Textil/Synthetik' 'Kunststoff/Textil'
#  'Baumwolle' 'Naturkautschuk' 'Neopren' 'AirMesh' 'Gummi/Textil'
#  'Leder/Synthetik' 'Mesh' 'Soft Synthetic']
# ['print' 'unifarben' 'gestreift' 'undefined' 'animal print' 'bunt'
#  'geblümt' 'meliert' 'gepunktet' 'kariert' 'Camouflage' 'Farbverlauf'
#  'Fotoprint' 'Paisley' 'Fischgrat' 'Nadelstreifen']

# %%
#Distribution of product_group.
sns.countplot(df['product_group'],label="Count",alpha=0.9)
plt.xticks(rotation=90)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['price_cluster'],label="Count",alpha=0.9)
plt.xticks(rotation=60)

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_encoded = df_encoded[['query','price_cluster','product_group','silhouette','brand','color','upper_material','pattern','label']]
corr = df_encoded.corr(method='pearson')
sns.heatmap(corr)
plt.show()

# %%
#how many product in total.
df.groupby('product_group')['label'].count()
# Out:
# product_group
# accessoires     186
# beach_wear        6
# beauty           25
# clothing       1230
# equipment        15
# nightwear         5
# other             1
# shoe            679
# underwear        13
# Name: label, dtype: int64

# %%
#How many product are shown to the user wrongly !
df.groupby('product_group')['label'].sum()
# Out:
# product_group
# accessoires     38
# beach_wear       6
# beauty           6
# clothing       214
# equipment       10
# nightwear        3
# other            0
# shoe           110
# underwear       11
# Name: label, dtype: int64

# %% [markdown]
# # Algorithm

# %%
# Becuse the labels are categorical, we apply label encoder to make it numerical.
df_encoded=df.copy() 
label_encoder = preprocessing.LabelEncoder()

values = df_encoded["query"].unique().tolist() # we want to make dictionary with values and keys, 
#to be able to get back to categorical for query.


df_encoded["query"] = label_encoder.fit_transform(df_encoded["query"]).astype('float64')
df_encoded["price_cluster"] = label_encoder.fit_transform(df_encoded["price_cluster"]).astype('float64')
df_encoded["product_group"] = label_encoder.fit_transform(df_encoded["product_group"].apply(str)).astype('float64')
df_encoded["silhouette"] = label_encoder.fit_transform(df_encoded["silhouette"].apply(str)).astype('float64')
df_encoded["brand"] = label_encoder.fit_transform(df_encoded["brand"].apply(str)).astype('float64')
df_encoded["upper_material"] = label_encoder.fit_transform(df_encoded["upper_material"].apply(str)).astype('float64')
df_encoded["pattern"] = label_encoder.fit_transform(df_encoded["pattern"].apply(str)).astype('float64')
df_encoded["color"] = label_encoder.fit_transform(df_encoded["color"].apply(str)).astype('float64')


keys= df_encoded["query"].unique().tolist()

encoded_dic={}

for key,value in zip(keys,values):
    encoded_dic[key] = value

# %%
encoded_dic
# Out:
# {24.0: 't-shirt dolce gabbana',
#  21.0: 'selected femme boots',
#  11.0: 'hairband sport',
#  12.0: 'halskragenpullover',
#  23.0: 'stiefeletten pepe jeans',
#  3.0: 'barney jacke',
#  7.0: 'chelsea wide',
#  5.0: 'california west coast pullover',
#  6.0: 'carhartt wip windbreaker',
#  20.0: 'save the duck mäntel damen',
#  8.0: 'collegejacken vintage',
#  9.0: 'converse schuhe herz',
#  17.0: 'naketano damen kapuzenjacken',
#  22.0: 'sonnenbrille chanel',
#  4.0: 'british knights master lo',
#  0.0: 'aigle stiefel',
#  1.0: 'asics gel venture 8',
#  25.0: 'tshirt kleid kurz',
#  15.0: 'jumpsuits kariert',
#  10.0: 'damenchino',
#  14.0: 'joggpants kinder',
#  2.0: 'baggy trackpant',
#  26.0: 'wanderschuhe lowa kinder',
#  19.0: 'regenjacke joules',
#  18.0: 'nike pullover vintage',
#  16.0: 'lacoste taschen sale',
#  13.0: 'jogging cargo'}

# %%
#we remove the feature commodity_group. it dosent add any value for the model.
df_encoded.drop(["commodity_group"], inplace=True, axis=1)

# %%
feature_cols = ['query','price_cluster','product_group','silhouette','brand','color','upper_material','pattern']
x_features = df_encoded[feature_cols]
y_label = df_encoded['label']
X_train, X_test, y_train, y_test = train_test_split(x_features, y_label, test_size=0.2, random_state=100) # 80% training and 20% test

#Building Decision Tree Model
clf = DecisionTreeClassifier()
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %% [markdown]
# # Evaluation

# %% [markdown]
# Dictionary named "results" containing mean accuracy, precision, recall and F1-score over all queries as {'accuracy':value, 'precision':value,...}

# %%
results={"Accuracy":metrics.accuracy_score(y_test, y_pred), "precision":metrics.precision_score(y_test, y_pred),
        "recall":metrics.recall_score(y_test, y_pred), "f1-score":metrics.f1_score(y_test, y_pred) }
results
# Out:
# {'Accuracy': 0.9074074074074074,
#  'precision': 0.7872340425531915,
#  'recall': 0.7872340425531915,
#  'f1-score': 0.7872340425531915}

# %% [markdown]
# Dictionary named "query_results" containing accuracy, precision, recall and F1-score for each query as {'query1':{'accuracy':value,'precision':value,...},'query2':{...}}

# %%
X_test = X_test.groupby('query')
X_tests={x:X_test.get_group(x) for x in X_test.groups}
#print (X_tests)


query_results = []

for q in X_tests.keys():
    y_pred = clf.predict(X_tests[q])
    #X_tests[q].index  
    gt= y_test[X_tests[q].index]
    query_results.append({encoded_dic[q]:{"Accuracy":round(metrics.accuracy_score(gt, y_pred),2), "precision":round(metrics.precision_score(gt, y_pred),2),
        "recall":round(metrics.recall_score(gt, y_pred),2), "f1-score":round(metrics.f1_score(gt, y_pred),2)}})

print(query_results)
# Out:
# [{'aigle stiefel': {'Accuracy': 0.89, 'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75}}, {'asics gel venture 8': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'baggy trackpant': {'Accuracy': 0.84, 'precision': 0.5, 'recall': 1.0, 'f1-score': 0.67}}, {'barney jacke': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'british knights master lo': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'california west coast pullover': {'Accuracy': 0.87, 'precision': 1.0, 'recall': 0.67, 'f1-score': 0.8}}, {'carhartt wip windbreaker': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'chelsea wide': {'Accuracy': 0.92, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0}}, {'collegejacken vintage': {'Accuracy': 0.9, 'precision': 0.6, 'recall': 1.0, 'f1-score': 0.75}}, {'converse schuhe herz': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'damenchino': {'Accuracy': 1.0, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0}}, {'hairband sport': {'Accuracy': 0.72, 'precision': 0.88, 'recall': 0.64, 'f1-score': 0.74}}, {'halskragenpullover': {'Accuracy': 0.94, 'precision': 0.83, 'recall': 1.0, 'f1-score': 0.91}}, {'jogging cargo': {'Accuracy': 0.79, 'precision': 0.67, 'recall': 0.5, 'f1-score': 0.57}}, {'joggpants kinder': {'Accuracy': 0.92, 'precision': 0.8, 'recall': 1.0, 'f1-score': 0.89}}, {'jumpsuits kariert': {'Accuracy': 0.76, 'precision': 0.71, 'recall': 0.71, 'f1-score': 0.71}}, {'lacoste taschen sale': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'naketano damen kapuzenjacken': {'Accuracy': 0.94, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0}}, {'nike pullover vintage': {'Accuracy': 0.94, 'precision': 1.0, 'recall': 0.67, 'f1-score': 0.8}}, {'regenjacke joules': {'Accuracy': 0.95, 'precision': 1.0, 'recall': 0.91, 'f1-score': 0.95}}, {'save the duck mäntel damen': {'Accuracy': 0.94, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0}}, {'selected femme boots': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'sonnenbrille chanel': {'Accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}}, {'stiefeletten pepe jeans': {'Accuracy': 0.9, 'precision': 0.5, 'recall': 1.0, 'f1-score': 0.67}}, {'t-shirt dolce gabbana': {'Accuracy': 0.86, 'precision': 1.0, 'recall': 0.78, 'f1-score': 0.88}}, {'tshirt kleid kurz': {'Accuracy': 0.64, 'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6}}, {'wanderschuhe lowa kinder': {'Accuracy': 0.86, 'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5}}]
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1493: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_tests
# Out:
# {'aigle stiefel':               query price_cluster commodity_group product_group   silhouette  \
#  1200  aigle stiefel        medium        1-2-K-02          shoe  ankle_boots
#  1201  aigle stiefel        medium      4-2-J-01-1     underwear     stocking
#  1202  aigle stiefel        medium        1-2-K-02          shoe  ankle_boots
#  1203  aigle stiefel        medium      4-4-A-01-2          shoe        boots
#  1204  aigle stiefel        medium      8-2-F-01-5     underwear     stocking
#  ...             ...           ...             ...           ...          ...
#  1275  aigle stiefel          high      4-2-A-01-1          shoe     low_shoe
#  1276  aigle stiefel        medium        1-2-K-01          shoe  ankle_boots
#  1277  aigle stiefel           low         1-5-L-3          shoe        boots
#  1278  aigle stiefel        medium      4-4-C-01-2          shoe        boots
#  1279  aigle stiefel        medium        1-2-K-02          shoe  ankle_boots
#
#              brand    color    upper_material    pattern  label
#  1200          UGG    braun             Leder  undefined      0
#  1201        FALKE     grau         undefined  undefined      0
#  1202          UGG  schwarz             Leder  unifarben      0
#  1203       Viking  schwarz    Naturkautschuk  unifarben      0
#  1204        FALKE    beige         undefined  unifarben      1
#  ...           ...      ...               ...        ...    ...
#  1275       Scarpa     blau  Leder und Textil      print      0
#  1276     Shepherd    braun      Veloursleder  unifarben      0
#  1277       MADSea     blau      Gummi/Textil  unifarben      0
#  1278       Viking     grau   Leder/Synthetik  undefined      0
#  1279  Panama Jack    braun             Leder  unifarben      0
#
#  [80 rows x 10 columns],
#  'asics gel venture 8':                     query price_cluster commodity_group product_group  \
#  1280  asics gel venture 8          high        1-6-D-05          shoe
#  1281  asics gel venture 8          high      4-2-A-03-2          shoe
#  1282  asics gel venture 8          high      4-2-A-03-1          shoe
#  1283  asics gel venture 8          high      4-2-A-03-2          shoe
#  1284  asics gel venture 8          high      4-2-A-03-2          shoe
#  ...                   ...           ...             ...           ...
#  1355  asics gel venture 8          high      4-2-A-03-3          shoe
#  1356  asics gel venture 8          high      4-2-A-03-1          shoe
#  1357  asics gel venture 8          high     4-2-A-03-10          shoe
#  1358  asics gel venture 8          high      4-2-A-03-2          shoe
#  1359  asics gel venture 8          high     4-2-A-03-10          shoe
#
#       silhouette  brand    color     upper_material    pattern  label
#  1280    sneaker  ASICS     grau               Mesh  undefined      0
#  1281   low_shoe  ASICS     blau  Kunststoff/Textil  undefined      0
#  1282   low_shoe  ASICS  schwarz   Textil/Synthetik  undefined      0
#  1283   low_shoe  ASICS     grau  Kunststoff/Textil      print      0
#  1284   low_shoe  ASICS  schwarz  Kunststoff/Textil      print      0
#  ...         ...    ...      ...                ...        ...    ...
#  1355   low_shoe  ASICS      rot  Kunststoff/Textil  undefined      0
#  1356   low_shoe  ASICS  schwarz  Kunststoff/Textil      print      0
#  1357   low_shoe  ASICS     grau  Kunststoff/Textil  undefined      0
#  1358   low_shoe  ASICS    weiss  Kunststoff/Textil      print      0
#  1359   low_shoe  ASICS     grau  Kunststoff/Textil  undefined      0
#
#  [80 rows x 10 columns],
#  'baggy trackpant':                 query price_cluster commodity_group product_group  \
#  1680  baggy trackpant        medium      2-2-G-6-01      clothing
#  1681  baggy trackpant        medium      2-2-E-6-02      clothing
#  1682  baggy trackpant        medium         2-2-E-2      clothing
#  1683  baggy trackpant        medium      2-2-E-1-03      clothing
#  1684  baggy trackpant        medium         2-2-E-5      clothing
#  ...               ...           ...             ...           ...
#  1755  baggy trackpant        medium      2-2-E-1-03      clothing
#  1756  baggy trackpant        medium      2-2-O-1-01      clothing
#  1757  baggy trackpant         entry      2-2-G-6-04      clothing
#  1758  baggy trackpant           low      2-2-T-2-02      clothing
#  1759  baggy trackpant        medium      2-2-G-6-01      clothing
#
#         silhouette             brand    color upper_material    pattern  label
#  1680      trouser         Karl Kani     blau      undefined  undefined      0
#  1681      trouser      Jaded London     grau      undefined    Paisley      0
#  1682      trouser  Kickers Classics     grau      undefined  unifarben      0
#  1683      trouser           Dickies     grau      undefined  unifarben      0
#  1684      trouser           Dickies     oliv      undefined  unifarben      0
#  ...           ...               ...      ...            ...        ...    ...
#  1755      trouser               HUF     oliv      undefined      print      0
#  1756  t_shirt_top      Jaded London     grau      undefined    Paisley      1
#  1757      trouser              Next  schwarz      undefined  undefined      0
#  1758         coat            Topman     grün      undefined      print      1
#  1759      trouser         Karl Kani     blau      undefined  undefined      0
#
#  [80 rows x 10 columns],
#  'barney jacke':             query price_cluster commodity_group product_group silhouette  \
#  400  barney jacke          high      2-2-T-8-01      clothing       coat
#  401  barney jacke        medium      2-2-T-8-01      clothing       coat
#  402  barney jacke          high      2-2-T-8-01      clothing       coat
#  403  barney jacke           low     2-1-U-04-02      clothing       coat
#  404  barney jacke          high      2-2-T-8-01      clothing       coat
#  ..            ...           ...             ...           ...        ...
#  475  barney jacke        medium      2-2-D-3-01      clothing      shirt
#  476  barney jacke        medium      2-2-T-8-03      clothing      shirt
#  477  barney jacke          high      2-2-T-8-03      clothing       coat
#  478  barney jacke          high      2-2-T-8-01      clothing       coat
#  479  barney jacke          high      2-2-T-8-02      clothing       coat
#
#                                      brand    color upper_material    pattern  \
#  400                                 Tigha    braun      undefined  unifarben
#  401                                 Gipsy      rot      undefined  unifarben
#  402                                 Tigha  schwarz      undefined  undefined
#  403                          Stradivarius  schwarz      undefined  unifarben
#  404  Royal Denim Division by Jack & Jones  schwarz      undefined  unifarben
#  ..                                    ...      ...            ...        ...
#  475                                G-Star     blau      undefined  undefined
#  476                         Freaky Nation     grau      undefined  unifarben
#  477                               Be Edgy  schwarz      undefined  unifarben
#  478                                G-Star  schwarz      undefined  unifarben
#  479                              Superdry  schwarz      undefined  unifarben
#
#       label
#  400      0
#  401      0
#  402      0
#  403      0
#  404      0
#  ..     ...
#  475      1
#  476      0
#  477      0
#  478      0
#  479      0
#
#  [80 rows x 10 columns],
#  'british knights master lo':                           query price_cluster commodity_group product_group  \
#  1120  british knights master lo           low       1-1-AD-01          shoe
#  1121  british knights master lo           low        1-2-O-01          shoe
#  1122  british knights master lo           low        1-2-O-01          shoe
#  1123  british knights master lo           low        1-2-O-01          shoe
#  1124  british knights master lo         entry        1-2-N-01          shoe
#  ...                         ...           ...             ...           ...
#  1195  british knights master lo           low        1-2-O-01          shoe
#  1196  british knights master lo           low        1-2-O-02          shoe
#  1197  british knights master lo         entry           1-2-O          shoe
#  1198  british knights master lo           low        1-2-O-01          shoe
#  1199  british knights master lo           low        1-2-O-03          shoe
#
#       silhouette             brand    color            upper_material  \
#  1120    sneaker   British Knights     grau                 Baumwolle
#  1121    sneaker           Mustang     blau                    Textil
#  1122    sneaker           Levi's®    weiss        Lederimitat/Textil
#  1123    sneaker           Mustang     grau  hochwertiges Lederimitat
#  1124    sneaker          Pier One    weiss  hochwertiges Lederimitat
#  ...         ...               ...      ...                       ...
#  1195    sneaker           Levi's®    weiss  hochwertiges Lederimitat
#  1196    sneaker          s.Oliver     grau          Leder und Textil
#  1197    sneaker          Pier One    weiss        Lederimitat/Textil
#  1198    sneaker           Mustang     grau        Lederimitat/Textil
#  1199    sneaker  Dockers by Gerli  schwarz         Kunststoff/Textil
#
#          pattern  label
#  1120  unifarben      0
#  1121  undefined      0
#  1122  undefined      0
#  1123      print      0
#  1124  unifarben      0
#  ...         ...    ...
#  1195      print      0
#  1196  undefined      0
#  1197  undefined      0
#  1198  unifarben      0
#  1199    meliert      0
#
#  [80 rows x 10 columns],
#  'california west coast pullover':                               query price_cluster commodity_group  \
#  560  california west coast pullover           low     2-1-J-04-02
#  561  california west coast pullover         entry     2-1-J-04-02
#  562  california west coast pullover           low     2-1-J-04-01
#  563  california west coast pullover           low     2-1-J-04-02
#  564  california west coast pullover           low        2-1-D-06
#  ..                              ...           ...             ...
#  635  california west coast pullover         entry     2-1-J-04-02
#  636  california west coast pullover           low     2-1-J-03-01
#  637  california west coast pullover           low        2-1-D-04
#  638  california west coast pullover           low     2-1-J-04-02
#  639  california west coast pullover        medium     2-1-J-04-02
#
#      product_group   silhouette           brand    color upper_material  \
#  560      clothing     pullover       PULL&BEAR     lila      undefined
#  561      clothing     pullover       PULL&BEAR     pink      undefined
#  562      clothing     pullover        Even&Odd      rot      undefined
#  563      clothing     pullover        Even&Odd     grün      undefined
#  564      clothing  t_shirt_top     Gina Tricot    weiss      undefined
#  ..            ...          ...             ...      ...            ...
#  635      clothing     pullover           Monki     grün      undefined
#  636      clothing     cardigan        Even&Odd  schwarz      undefined
#  637      clothing     pullover           Monki     grün      undefined
#  638      clothing     pullover     Gina Tricot    weiss      undefined
#  639      clothing     pullover  American Eagle    braun      undefined
#
#         pattern  label
#  560  undefined      0
#  561  undefined      0
#  562  unifarben      0
#  563  unifarben      0
#  564      print      1
#  ..         ...    ...
#  635  unifarben      0
#  636  unifarben      0
#  637  unifarben      0
#  638  undefined      0
#  639      print      0
#
#  [80 rows x 10 columns],
#  'carhartt wip windbreaker':                         query price_cluster commodity_group product_group  \
#  640  carhartt wip windbreaker           low      2-2-T-3-08      clothing
#  641  carhartt wip windbreaker        medium      2-2-T-3-08      clothing
#  642  carhartt wip windbreaker           low      2-2-T-3-09      clothing
#  643  carhartt wip windbreaker        medium      2-2-T-3-08      clothing
#  644  carhartt wip windbreaker        medium        8-2-H-02      clothing
#  ..                        ...           ...             ...           ...
#  715  carhartt wip windbreaker           low      2-2-T-3-08      clothing
#  716  carhartt wip windbreaker        medium      2-2-T-3-08      clothing
#  717  carhartt wip windbreaker           low      2-2-T-3-08      clothing
#  718  carhartt wip windbreaker           low      2-2-T-3-08      clothing
#  719  carhartt wip windbreaker        medium      2-2-T-3-08      clothing
#
#      silhouette          brand    color upper_material    pattern  label
#  640       coat       Superdry   orange      undefined  undefined      0
#  641       coat     Timberland  schwarz      undefined  undefined      0
#  642       coat       Superdry     blau      undefined  undefined      0
#  643       coat   Carhartt WIP     blau      undefined  undefined      0
#  644    trouser   Carhartt WIP  schwarz      undefined  undefined      1
#  ..         ...            ...      ...            ...        ...    ...
#  715       coat  Obey Clothing     blau      undefined  undefined      0
#  716       coat   Carhartt WIP  schwarz      undefined  unifarben      0
#  717       coat        Ellesse     blau      undefined  undefined      0
#  718       coat           Vans  schwarz      undefined  undefined      0
#  719       coat   Carhartt WIP      rot      undefined      print      0
#
#  [80 rows x 10 columns],
#  'chelsea wide':             query price_cluster commodity_group product_group   silhouette  \
#  480  chelsea wide           low         1-1-N-Z          shoe  ankle_boots
#  481  chelsea wide        medium        1-1-N-05          shoe     low_shoe
#  482  chelsea wide        medium        1-1-N-03          shoe  ankle_boots
#  483  chelsea wide        medium        1-1-N-02         other       system
#  484  chelsea wide         entry        2-1-D-06      clothing  t_shirt_top
#  ..            ...           ...             ...           ...          ...
#  555  chelsea wide        medium       1-1-AA-01          shoe  ankle_boots
#  556  chelsea wide           low         1-1-N-Z          shoe  ankle_boots
#  557  chelsea wide        medium        1-1-N-02          shoe  ankle_boots
#  558  chelsea wide        medium        1-1-N-05          shoe  ankle_boots
#  559  chelsea wide           low        1-1-N-02          shoe  ankle_boots
#
#                  brand    color            upper_material    pattern  label
#  480        Anna Field     blau  hochwertiges Lederimitat  unifarben      0
#  481  Clarks Originals    braun                     Leder  unifarben      0
#  482         Pikolinos  schwarz                     Leder  undefined      0
#  483            Clarks  schwarz                     Leder  undefined      0
#  484        Anna Field     grün                 undefined  unifarben      1
#  ..                ...      ...                       ...        ...    ...
#  555  Felmini Wide Fit    braun                     Leder  undefined      0
#  556             Evans  schwarz  hochwertiges Lederimitat  unifarben      0
#  557            Clarks     blau                     Nubuk  unifarben      0
#  558        Anna Field    braun                     Leder  unifarben      0
#  559          Pier One    braun  hochwertiges Lederimitat  unifarben      0
#
#  [80 rows x 10 columns],
#  'collegejacken vintage':                      query price_cluster commodity_group product_group  \
#  800  collegejacken vintage           low        2-1-G-03      clothing
#  801  collegejacken vintage           low        2-1-G-03      clothing
#  802  collegejacken vintage          high      4-1-G-20-1      clothing
#  803  collegejacken vintage        medium        2-1-D-09      clothing
#  804  collegejacken vintage         entry     2-1-U-04-04      clothing
#  ..                     ...           ...             ...           ...
#  875  collegejacken vintage        medium     2-1-J-04-02      clothing
#  876  collegejacken vintage         entry        2-1-G-03      clothing
#  877  collegejacken vintage        medium     2-1-J-04-02      clothing
#  878  collegejacken vintage           low        2-1-G-03      clothing
#  879  collegejacken vintage           low        2-1-G-03      clothing
#
#        silhouette           brand    color upper_material    pattern  label
#  800         coat       Vero Moda     pink      undefined  unifarben      0
#  801         coat  Urban Classics  schwarz      undefined  undefined      0
#  802         coat         New Era  schwarz      undefined  gestreift      0
#  803  t_shirt_top       Von Dutch    weiss      undefined      print      1
#  804         coat       PULL&BEAR    braun      undefined  undefined      0
#  ..           ...             ...      ...            ...        ...    ...
#  875     pullover   America Today     grün      undefined      print      1
#  876         coat  Urban Classics  schwarz      undefined  unifarben      0
#  877     pullover  American Eagle    braun      undefined      print      1
#  878         coat       Vero Moda  schwarz      undefined    geblümt      0
#  879         coat            ONLY     blau      undefined    geblümt      0
#
#  [80 rows x 10 columns],
#  'converse schuhe herz':                     query price_cluster commodity_group product_group  \
#  880  converse schuhe herz        medium       1-1-AD-02          shoe
#  881  converse schuhe herz           low       1-1-AD-02          shoe
#  882  converse schuhe herz           low     2-1-I-01-01      clothing
#  883  converse schuhe herz           low        1-5-N-01          shoe
#  884  converse schuhe herz        medium       1-1-AD-01          shoe
#  ..                    ...           ...             ...           ...
#  955  converse schuhe herz        medium        1-5-N-01          shoe
#  956  converse schuhe herz        medium        1-5-N-01          shoe
#  957  converse schuhe herz        medium       1-1-AD-02          shoe
#  958  converse schuhe herz        medium       1-1-AD-02          shoe
#  959  converse schuhe herz           low        1-5-N-01          shoe
#
#      silhouette                 brand    color            upper_material  \
#  880    sneaker              Converse    weiss  hochwertiges Lederimitat
#  881    sneaker              Converse     grün                    Textil
#  882   cardigan  BDG Urban Outfitters     grün                 undefined
#  883    sneaker              Converse  schwarz                    Textil
#  884    sneaker              Converse    weiss                    Textil
#  ..         ...                   ...      ...                       ...
#  955    sneaker              Converse  schwarz                    Textil
#  956    sneaker              Converse  schwarz              Veloursleder
#  957    sneaker              Converse    weiss                    Textil
#  958    sneaker              Converse     blau                    Textil
#  959    sneaker              Converse  schwarz                    Textil
#
#            pattern  label
#  880     unifarben      0
#  881     unifarben      0
#  882     unifarben      1
#  883  animal print      0
#  884     unifarben      0
#  ..            ...    ...
#  955     unifarben      0
#  956     unifarben      0
#  957     unifarben      0
#  958     unifarben      0
#  959     undefined      0
#
#  [80 rows x 10 columns],
#  'damenchino':            query price_cluster commodity_group product_group silhouette  \
#  1520  damenchino           low        2-1-A-02      clothing    trouser
#  1521  damenchino           low        2-1-A-02      clothing    trouser
#  1522  damenchino        medium        2-1-A-15      clothing    trouser
#  1523  damenchino        medium        2-1-A-02      clothing    trouser
#  1524  damenchino           low        2-1-A-02      clothing    trouser
#  ...          ...           ...             ...           ...        ...
#  1595  damenchino           low        2-1-A-02      clothing    trouser
#  1596  damenchino           low        2-1-A-13      clothing    trouser
#  1597  damenchino           low        2-1-A-02      clothing    trouser
#  1598  damenchino        medium        2-1-A-15      clothing    trouser
#  1599  damenchino          high      4-1-E-01-2      clothing    trouser
#
#                    brand    color upper_material    pattern  label
#  1520            Desires  schwarz      undefined  unifarben      0
#  1521               ONLY     blau      undefined  unifarben      0
#  1522  Karen by Simonsen     grau      undefined    meliert      0
#  1523      Scotch & Soda    beige      undefined  unifarben      0
#  1524           s.Oliver     blau      undefined  unifarben      0
#  ...                 ...      ...            ...        ...    ...
#  1595         TOM TAILOR     grün      undefined  unifarben      0
#  1596               Vila     blau      undefined  unifarben      0
#  1597             Esprit     grau      undefined  unifarben      0
#  1598              comma  schwarz      undefined  unifarben      0
#  1599              Vaude     grün      undefined  unifarben      0
#
#  [80 rows x 10 columns],
#  'hairband sport':               query price_cluster commodity_group product_group  \
#  160  hairband sport           low      4-1-N-16-1     equipment
#  161  hairband sport        medium      4-1-D-05-2      clothing
#  162  hairband sport           low        5-1-L-06   accessoires
#  163  hairband sport        medium     3-1-J-02-03        beauty
#  164  hairband sport         entry      4-1-N-02-2     equipment
#  ..              ...           ...             ...           ...
#  235  hairband sport           low      4-1-E-03-2      clothing
#  236  hairband sport         entry      4-1-N-02-5     equipment
#  237  hairband sport         entry      4-1-N-02-5     equipment
#  238  hairband sport         entry      4-1-N-02-2   accessoires
#  239  hairband sport         entry      4-4-E-03-6     equipment
#
#              silhouette             brand        color upper_material  \
#  160            fitness            Casall        beige      undefined
#  161        t_shirt_top             Craft      schwarz      undefined
#  162          jewellery              ONLY      schwarz      undefined
#  163   beauty_equipment          ZOË AYLA  sonderfarbe      undefined
#  164    other_equipment  Nike Performance         bunt      undefined
#  ..                 ...               ...          ...            ...
#  235            trouser             ASICS      schwarz      undefined
#  236    other_equipment  Nike Performance      schwarz      undefined
#  237            fitness            Casall        beige      undefined
#  238  other_accessoires  Nike Performance        weiss      undefined
#  239    other_equipment  Nike Performance      schwarz      undefined
#
#            pattern  label
#  160     undefined      1
#  161         print      1
#  162  animal print      0
#  163     undefined      0
#  164     unifarben      0
#  ..            ...    ...
#  235     unifarben      1
#  236         print      0
#  237     undefined      1
#  238         print      0
#  239         print      1
#
#  [80 rows x 10 columns],
#  'halskragenpullover':                   query price_cluster commodity_group product_group  \
#  240  halskragenpullover           low      2-2-G-4-04      clothing
#  241  halskragenpullover           low      2-2-Q-5-01      clothing
#  242  halskragenpullover          high      2-2-Q-5-01      clothing
#  243  halskragenpullover        medium     2-1-I-01-01      clothing
#  244  halskragenpullover           low         2-2-Q-8      clothing
#  ..                  ...           ...             ...           ...
#  315  halskragenpullover          high      2-2-T-8-03      clothing
#  316  halskragenpullover        medium      2-2-Q-5-01      clothing
#  317  halskragenpullover           low      2-2-Q-5-01      clothing
#  318  halskragenpullover           low      2-2-Q-5-01      clothing
#  319  halskragenpullover           low      2-2-Q-5-01      clothing
#
#      silhouette             brand    color upper_material    pattern  label
#  240    trouser               LTB  schwarz      undefined  unifarben      1
#  241   pullover      Jack & Jones      rot      undefined  unifarben      0
#  242   pullover       Club Monaco  schwarz      undefined  unifarben      0
#  243   pullover      camel active    weiss      undefined  unifarben      0
#  244   pullover           Bertoni    weiss      undefined  unifarben      0
#  ..         ...               ...      ...            ...        ...    ...
#  315       coat       DNR Jackets     grün      undefined  unifarben      1
#  316   pullover   Sand Copenhagen    weiss      undefined  unifarben      0
#  317   pullover  TOM TAILOR DENIM     grau      undefined    meliert      0
#  318   pullover            Esprit    weiss      undefined  unifarben      0
#  319   pullover        TOM TAILOR    braun      undefined  undefined      0
#
#  [80 rows x 10 columns],
#  'jogging cargo':               query price_cluster commodity_group product_group silhouette  \
#  2080  jogging cargo          high        2-1-A-05      clothing    trouser
#  2081  jogging cargo           low        2-1-A-05      clothing    trouser
#  2082  jogging cargo           low     2-1-B-01-01      clothing      skirt
#  2083  jogging cargo           low        2-1-A-13      clothing    trouser
#  2084  jogging cargo           low        2-1-A-05      clothing    trouser
#  ...             ...           ...             ...           ...        ...
#  2155  jogging cargo        medium        2-1-A-05      clothing    trouser
#  2156  jogging cargo         entry        2-1-S-05      clothing    trouser
#  2157  jogging cargo           low        2-1-A-05      clothing    trouser
#  2158  jogging cargo         entry         2-1-E-Z      clothing      shirt
#  2159  jogging cargo           low        2-1-A-13      clothing    trouser
#
#                   brand    color upper_material    pattern  label
#  2080  Max Mara Leisure    beige      undefined  unifarben      0
#  2081         Noisy May     grau      undefined    meliert      0
#  2082           Weekday     oliv      undefined  unifarben      1
#  2083        GINA LAURA     blau      undefined  undefined      0
#  2084        Sixth June  schwarz      undefined      print      0
#  ...                ...      ...            ...        ...    ...
#  2155    American Eagle     oliv      undefined  unifarben      0
#  2156         PULL&BEAR    braun      undefined  undefined      0
#  2157    Urban Classics  schwarz      undefined  unifarben      0
#  2158      Stradivarius     grau      undefined  undefined      0
#  2159             Monki  schwarz      undefined  unifarben      0
#
#  [80 rows x 10 columns],
#  'joggpants kinder':                  query price_cluster commodity_group product_group silhouette  \
#  1600  joggpants kinder           low     2-1-C-04-03      clothing      dress
#  1601  joggpants kinder           low     2-1-C-04-01      clothing      dress
#  1602  joggpants kinder        medium        2-1-N-03      clothing    trouser
#  1603  joggpants kinder        medium        2-1-A-05      clothing    trouser
#  1604  joggpants kinder           low        2-1-A-13      clothing    trouser
#  ...                ...           ...             ...           ...        ...
#  1675  joggpants kinder           low     2-1-C-04-03      clothing      dress
#  1676  joggpants kinder           low        2-1-A-13      clothing    trouser
#  1677  joggpants kinder           low        2-1-A-13      clothing    trouser
#  1678  joggpants kinder           low     2-1-C-04-03      clothing      dress
#  1679  joggpants kinder           low        2-1-A-13      clothing    trouser
#
#             brand    color upper_material        pattern  label
#  1600        ONLY  schwarz      undefined          print      1
#  1601        ONLY  schwarz      undefined      Fischgrat      1
#  1602       Soccx  schwarz      undefined      unifarben      0
#  1603  Street One  schwarz      undefined        meliert      0
#  1604        ONLY  schwarz      undefined      unifarben      0
#  ...          ...      ...            ...            ...    ...
#  1675        ONLY  schwarz      undefined        geblümt      0
#  1676       Kaffe    braun      undefined      undefined      0
#  1677   ONLY Tall  schwarz      undefined      unifarben      0
#  1678        ONLY     bunt      undefined      undefined      1
#  1679   ONLY Tall  schwarz      undefined  Nadelstreifen      0
#
#  [80 rows x 10 columns],
#  'jumpsuits kariert':                   query price_cluster commodity_group product_group  \
#  1440  jumpsuits kariert        medium        2-1-T-03      clothing
#  1441  jumpsuits kariert           low        2-1-T-03      clothing
#  1442  jumpsuits kariert          high        2-1-T-01      clothing
#  1443  jumpsuits kariert        medium        2-1-T-01      clothing
#  1444  jumpsuits kariert          high        2-1-T-01      clothing
#  ...                 ...           ...             ...           ...
#  1515  jumpsuits kariert          high         8-1-N-3    beach_wear
#  1516  jumpsuits kariert        medium     2-1-C-04-01      clothing
#  1517  jumpsuits kariert        medium        2-1-T-02      clothing
#  1518  jumpsuits kariert        medium     2-1-C-04-01      clothing
#  1519  jumpsuits kariert           low     2-1-C-04-01      clothing
#
#            silhouette           brand    color upper_material       pattern  \
#  1440  one_piece_suit        Superdry  schwarz      undefined       geblümt
#  1441  one_piece_suit   Molly Bracken     grün      undefined       geblümt
#  1442  one_piece_suit   Another-Label     grau      undefined       kariert
#  1443  one_piece_suit            ONLY     blau      undefined     undefined
#  1444  one_piece_suit     Lounge Nine    beige      undefined     unifarben
#  ...              ...             ...      ...            ...           ...
#  1515     beach_shirt          Diesel  schwarz      undefined         print
#  1516           dress      PETER HAHN     bunt      undefined  animal print
#  1517         trouser  Reebok Classic  schwarz      undefined     undefined
#  1518           dress        s.Oliver     gelb      undefined       kariert
#  1519           dress        Trendyol     pink      undefined  animal print
#
#        label
#  1440      0
#  1441      0
#  1442      0
#  1443      0
#  1444      0
#  ...     ...
#  1515      1
#  1516      1
#  1517      0
#  1518      1
#  1519      1
#
#  [80 rows x 10 columns],
#  'lacoste taschen sale':                      query price_cluster commodity_group product_group  \
#  2000  lacoste taschen sale        medium      5-1-H-04-5   accessoires
#  2001  lacoste taschen sale        medium      5-1-H-04-8   accessoires
#  2002  lacoste taschen sale        medium      5-1-H-04-8   accessoires
#  2003  lacoste taschen sale        medium     5-1-H-04-10   accessoires
#  2004  lacoste taschen sale        medium      5-1-H-04-3   accessoires
#  ...                    ...           ...             ...           ...
#  2075  lacoste taschen sale        medium      5-1-H-04-8   accessoires
#  2076  lacoste taschen sale        medium      5-1-H-04-5   accessoires
#  2077  lacoste taschen sale        medium      5-1-H-04-8   accessoires
#  2078  lacoste taschen sale        medium       1-1-AD-02          shoe
#  2079  lacoste taschen sale        medium     5-1-H-04-10   accessoires
#
#       silhouette           brand    color upper_material    pattern  label
#  2000        bag         Lacoste  schwarz      undefined  undefined      0
#  2001        bag         Lacoste      rot      undefined  unifarben      0
#  2002        bag         Lacoste     blau      undefined  undefined      0
#  2003        bag         Lacoste  schwarz      undefined  unifarben      0
#  2004        bag  Emporio Armani   silber      undefined  unifarben      0
#  ...         ...             ...      ...            ...        ...    ...
#  2075        bag         Lacoste  schwarz      undefined  unifarben      0
#  2076        bag           JOOP!     pink      undefined      print      0
#  2077        bag  Tommy Hilfiger    weiss      undefined  gestreift      0
#  2078    sneaker         Lacoste    weiss          Leder  undefined      1
#  2079        bag         Lacoste  schwarz      undefined  unifarben      0
#
#  [80 rows x 10 columns],
#  'naketano damen kapuzenjacken':                              query price_cluster commodity_group  \
#  960   naketano damen kapuzenjacken           low         2-1-G-Z
#  961   naketano damen kapuzenjacken           low     2-9-M-04-02
#  962   naketano damen kapuzenjacken        medium        2-1-T-03
#  963   naketano damen kapuzenjacken        medium     2-1-U-04-02
#  964   naketano damen kapuzenjacken           low     2-1-U-04-02
#  ...                            ...           ...             ...
#  1035  naketano damen kapuzenjacken           low     2-1-U-04-02
#  1036  naketano damen kapuzenjacken        medium         2-1-G-Z
#  1037  naketano damen kapuzenjacken        medium     2-1-U-02-02
#  1038  naketano damen kapuzenjacken           low     2-1-U-04-03
#  1039  naketano damen kapuzenjacken           low     2-1-U-04-02
#
#       product_group silhouette           brand    color upper_material  \
#  960       clothing       coat         Desires     blau      undefined
#  961       clothing       coat  alife & kickin     blau      undefined
#  962       clothing       coat  alife & kickin      rot      undefined
#  963       clothing       coat            myMo     oliv      undefined
#  964       clothing       coat         Desires      rot      undefined
#  ...            ...        ...             ...      ...            ...
#  1035      clothing       coat        Blendshe  schwarz      undefined
#  1036      clothing       coat        Naketano     blau      undefined
#  1037      clothing       coat         Ragwear  schwarz      undefined
#  1038      clothing       coat         Ragwear      rot      undefined
#  1039      clothing       coat        Blendshe     blau      undefined
#
#          pattern  label
#  960   unifarben      0
#  961   undefined      0
#  962   unifarben      0
#  963   unifarben      0
#  964   unifarben      0
#  ...         ...    ...
#  1035  unifarben      0
#  1036      print      0
#  1037      print      0
#  1038      print      0
#  1039    meliert      0
#
#  [80 rows x 10 columns],
#  'nike pullover vintage':                       query price_cluster commodity_group product_group  \
#  1920  nike pullover vintage        medium     2-1-J-04-02      clothing
#  1921  nike pullover vintage        medium     2-1-J-04-02      clothing
#  1922  nike pullover vintage        medium      4-3-G-18-1      clothing
#  1923  nike pullover vintage        medium     2-1-J-04-02      clothing
#  1924  nike pullover vintage        medium     2-1-J-04-02      clothing
#  ...                     ...           ...             ...           ...
#  1995  nike pullover vintage          high      4-1-G-05-2      clothing
#  1996  nike pullover vintage        medium     2-1-J-04-01      clothing
#  1997  nike pullover vintage        medium     2-1-J-04-02      clothing
#  1998  nike pullover vintage        medium         2-2-S-1      clothing
#  1999  nike pullover vintage        medium        2-3-K-02      clothing
#
#         silhouette             brand    color upper_material    pattern  label
#  1920     pullover   Nike Sportswear  schwarz      undefined      print      0
#  1921     pullover   Nike Sportswear     grau      undefined  undefined      0
#  1922     pullover  Nike Performance  schwarz      undefined      print      0
#  1923     pullover   Nike Sportswear     lila      undefined  unifarben      0
#  1924     pullover   Nike Sportswear  schwarz      undefined      print      0
#  ...           ...               ...      ...            ...        ...    ...
#  1995     pullover  Nike Performance  schwarz      undefined    meliert      0
#  1996     pullover   Nike Sportswear     grau      undefined    meliert      0
#  1997     pullover   Nike Sportswear     grau      undefined    meliert      0
#  1998  t_shirt_top   Nike Sportswear     blau      undefined  undefined      0
#  1999     pullover   Nike Sportswear     grau      undefined      print      0
#
#  [80 rows x 10 columns],
#  'regenjacke joules':                   query price_cluster commodity_group product_group  \
#  1840  regenjacke joules           low        2-3-N-02      clothing
#  1841  regenjacke joules        medium        2-4-N-02      clothing
#  1842  regenjacke joules        medium        2-3-N-02      clothing
#  1843  regenjacke joules           low        1-6-J-01          shoe
#  1844  regenjacke joules           low        1-3-J-01          shoe
#  ...                 ...           ...             ...           ...
#  1915  regenjacke joules           low        1-6-J-01          shoe
#  1916  regenjacke joules        medium      4-3-C-01-1          shoe
#  1917  regenjacke joules           low        1-6-J-01          shoe
#  1918  regenjacke joules        medium        2-4-N-03      clothing
#  1919  regenjacke joules           low        1-6-J-01          shoe
#
#                  silhouette      brand    color  upper_material    pattern  \
#  1840                  coat  Playshoes      rot       undefined  undefined
#  1841                  coat  Playshoes   türkis       undefined      print
#  1842                  coat  Playshoes     pink       undefined      print
#  1843                 boots   Bisgaard  schwarz      Kunststoff  unifarben
#  1844                 boots   Bisgaard     pink  Naturkautschuk    geblümt
#  ...                    ...        ...      ...             ...        ...
#  1915                 boots   Bisgaard     blau  Naturkautschuk  unifarben
#  1916                 boots     Viking     blau  Naturkautschuk  unifarben
#  1917                 boots  Bergstein     pink  Naturkautschuk  unifarben
#  1918  combination_clothing  Playshoes     blau       undefined      print
#  1919                 boots  Bergstein     grün  Naturkautschuk  undefined
#
#        label
#  1840      0
#  1841      0
#  1842      0
#  1843      1
#  1844      1
#  ...     ...
#  1915      1
#  1916      1
#  1917      1
#  1918      0
#  1919      1
#
#  [80 rows x 10 columns],
#  'save the duck mäntel damen':                           query price_cluster commodity_group product_group  \
#  720  save the duck mäntel damen        medium     2-1-U-04-02      clothing
#  721  save the duck mäntel damen        medium     2-1-U-02-01      clothing
#  722  save the duck mäntel damen        medium     2-1-U-03-01      clothing
#  723  save the duck mäntel damen        medium     2-1-U-04-02      clothing
#  724  save the duck mäntel damen          high       1-1-AD-04          shoe
#  ..                          ...           ...             ...           ...
#  795  save the duck mäntel damen          high     2-1-U-03-01      clothing
#  796  save the duck mäntel damen        medium     2-1-U-04-02      clothing
#  797  save the duck mäntel damen          high     2-1-U-03-01      clothing
#  798  save the duck mäntel damen        medium     2-1-U-04-02      clothing
#  799  save the duck mäntel damen          high        2-1-N-02      clothing
#
#        silhouette              brand    color    upper_material    pattern  \
#  720         coat      Save the duck     blau         undefined  unifarben
#  721         coat          No.1 Como  schwarz         undefined  unifarben
#  722         coat  Frieda & Freddies     blau         undefined  unifarben
#  723         coat      Save the duck    weiss         undefined  unifarben
#  724  ankle_boots             Blauer      rot  Leder und Textil  unifarben
#  ..           ...                ...      ...               ...        ...
#  795         coat          Bomboogie     grün         undefined  unifarben
#  796         coat      Save the duck     blau         undefined  unifarben
#  797         coat         Finn Flare     blau         undefined  unifarben
#  798         coat      Save the duck     grün         undefined  unifarben
#  799      trouser       Liu Jo Jeans     grau         undefined  undefined
#
#       label
#  720      0
#  721      0
#  722      0
#  723      0
#  724      1
#  ..     ...
#  795      0
#  796      0
#  797      0
#  798      0
#  799      1
#
#  [80 rows x 10 columns],
#  'selected femme boots':                     query price_cluster commodity_group product_group  \
#  80   selected femme boots          high        1-1-X-05          shoe
#  81   selected femme boots        medium        1-1-X-05          shoe
#  82   selected femme boots        medium        1-1-N-05          shoe
#  83   selected femme boots        medium         1-1-N-Z          shoe
#  84   selected femme boots        medium        1-1-X-05          shoe
#  ..                    ...           ...             ...           ...
#  155  selected femme boots        medium        1-1-X-05          shoe
#  156  selected femme boots        medium     2-1-U-04-02      clothing
#  157  selected femme boots        medium        1-1-N-04          shoe
#  158  selected femme boots        medium     2-1-U-04-02      clothing
#  159  selected femme boots        medium       1-1-AD-02          shoe
#
#        silhouette          brand    color upper_material       pattern  label
#  80   ankle_boots     Blackstone  schwarz          Leder     unifarben      0
#  81   ankle_boots           Zign  schwarz   Veloursleder     unifarben      0
#  82   ankle_boots           ALDO    braun          Leder     unifarben      0
#  83   ankle_boots       Pavement     grün   Veloursleder  animal print      0
#  84   ankle_boots  Shoe The Bear  schwarz          Leder     unifarben      0
#  ..           ...            ...      ...            ...           ...    ...
#  155  ankle_boots       Pavement  schwarz          Leder     unifarben      0
#  156         coat          Envii    beige      undefined     unifarben      1
#  157  ankle_boots       Pavement     grün   Veloursleder     unifarben      0
#  158         coat            YAS    braun      undefined     unifarben      0
#  159  ankle_boots         Bianco    beige          Leder     unifarben      0
#
#  [80 rows x 10 columns],
#  'sonnenbrille chanel':                     query price_cluster commodity_group product_group  \
#  1040  sonnenbrille chanel           low      5-3-G-05-2   accessoires
#  1041  sonnenbrille chanel          high      5-3-M-02-2   accessoires
#  1042  sonnenbrille chanel          high        2-4-C-06      clothing
#  1043  sonnenbrille chanel           low        2-4-C-06      clothing
#  1044  sonnenbrille chanel          high      5-3-G-05-2   accessoires
#  ...                   ...           ...             ...           ...
#  1115  sonnenbrille chanel          high      5-3-G-05-2   accessoires
#  1116  sonnenbrille chanel          high      5-3-G-05-2   accessoires
#  1117  sonnenbrille chanel          high        2-4-G-02      clothing
#  1118  sonnenbrille chanel          high     2-3-D-03-02      clothing
#  1119  sonnenbrille chanel        medium        2-4-B-04      clothing
#
#            silhouette             brand  color upper_material       pattern  \
#  1040         glasses         Sunnylife   gelb      undefined         print
#  1041        headgear           Versace   bunt      undefined         print
#  1042         trouser     BOSS Kidswear   blau      undefined     unifarben
#  1043         trouser              Next   blau      undefined     unifarben
#  1044         glasses           Ray-Ban  braun      undefined  animal print
#  ...              ...               ...    ...            ...           ...
#  1115         glasses  Stella McCartney    rot      undefined     unifarben
#  1116         glasses           Ray-Ban  braun      undefined  animal print
#  1117     t_shirt_top   The Marc Jacobs   grau      undefined         print
#  1118  one_piece_suit     BOSS Kidswear   grau      undefined       meliert
#  1119         trouser     BOSS Kidswear   blau      undefined         print
#
#        label
#  1040      0
#  1041      1
#  1042      1
#  1043      1
#  1044      0
#  ...     ...
#  1115      0
#  1116      0
#  1117      1
#  1118      1
#  1119      1
#
#  [80 rows x 10 columns],
#  'stiefeletten pepe jeans':                        query price_cluster commodity_group product_group  \
#  320  stiefeletten pepe jeans          high        1-1-N-03          shoe
#  321  stiefeletten pepe jeans        medium        1-1-N-03          shoe
#  322  stiefeletten pepe jeans          high        1-1-N-03          shoe
#  323  stiefeletten pepe jeans          high        1-1-N-03          shoe
#  324  stiefeletten pepe jeans           low         1-1-N-Z          shoe
#  ..                       ...           ...             ...           ...
#  395  stiefeletten pepe jeans        medium         2-1-E-Z      clothing
#  396  stiefeletten pepe jeans        medium        1-1-N-03          shoe
#  397  stiefeletten pepe jeans        medium     1-1-B-01-01          shoe
#  398  stiefeletten pepe jeans           low        1-1-N-03          shoe
#  399  stiefeletten pepe jeans          high        1-1-N-03          shoe
#
#        silhouette           brand    color            upper_material  \
#  320  ankle_boots            MJUS    braun                     Leder
#  321  ankle_boots     Bruno Premi  schwarz                     Leder
#  322  ankle_boots         Felmini  schwarz                     Leder
#  323  ankle_boots  Royal RepubliQ  schwarz                     Leder
#  324  ankle_boots       Bullboxer  schwarz                    Textil
#  ..           ...             ...      ...                       ...
#  395        shirt         Levi's®      rot                 undefined
#  396  ankle_boots           Unisa  schwarz                Kalbsleder
#  397        pumps         Felmini  schwarz                     Leder
#  398  ankle_boots        s.Oliver  schwarz  hochwertiges Lederimitat
#  399        pumps  Royal RepubliQ  schwarz                     Leder
#
#            pattern  label
#  320     unifarben      0
#  321     unifarben      0
#  322     unifarben      0
#  323     unifarben      0
#  324     unifarben      0
#  ..            ...    ...
#  395  animal print      1
#  396  animal print      0
#  397     unifarben      0
#  398  animal print      0
#  399     unifarben      0
#
#  [80 rows x 10 columns],
#  't-shirt dolce gabbana':                     query price_cluster commodity_group product_group  \
#  0   t-shirt dolce gabbana           low      4-2-B-01-1          shoe
#  1   t-shirt dolce gabbana           low         1-2-G-3          shoe
#  2   t-shirt dolce gabbana           low         1-2-G-4          shoe
#  3   t-shirt dolce gabbana          high         1-2-G-3          shoe
#  4   t-shirt dolce gabbana           low         1-2-C-1          shoe
#  ..                    ...           ...             ...           ...
#  75  t-shirt dolce gabbana           low         1-2-G-4          shoe
#  76  t-shirt dolce gabbana          high         2-2-F-5      clothing
#  77  t-shirt dolce gabbana           low      4-2-B-02-1          shoe
#  78  t-shirt dolce gabbana        medium      2-2-O-1-03      clothing
#  79  t-shirt dolce gabbana        medium      2-2-O-1-03      clothing
#
#            silhouette                  brand    color  \
#  0   backless_slipper     adidas Performance  schwarz
#  1   backless_slipper                  Guess  schwarz
#  2   backless_slipper         Tommy Hilfiger      rot
#  3   backless_slipper               MOSCHINO  schwarz
#  4           low_shoe               Pier One     gelb
#  ..               ...                    ...      ...
#  75  backless_slipper             TOM TAILOR     blau
#  76           trouser  Versace Jeans Couture  schwarz
#  77  backless_slipper     adidas Performance  schwarz
#  78       t_shirt_top       Glorious Gangsta    weiss
#  79       t_shirt_top     Calvin Klein Jeans  schwarz
#
#                upper_material    pattern  label
#  0                 Kunststoff      print      1
#  1                 Kunststoff  unifarben      1
#  2           Leder und Textil  gestreift      1
#  3   hochwertiges Lederimitat  unifarben      1
#  4                     Textil  unifarben      1
#  ..                       ...        ...    ...
#  75                    Textil  undefined      1
#  76                 undefined      print      0
#  77                Kunststoff  unifarben      1
#  78                 undefined  undefined      0
#  79                 undefined      print      0
#
#  [80 rows x 10 columns],
#  'tshirt kleid kurz':                   query price_cluster commodity_group product_group  \
#  1360  tshirt kleid kurz        medium     2-1-C-04-01      clothing
#  1361  tshirt kleid kurz          high        2-1-D-06      clothing
#  1362  tshirt kleid kurz           low        2-1-D-06      clothing
#  1363  tshirt kleid kurz          high     2-1-C-04-01      clothing
#  1364  tshirt kleid kurz           low     2-1-C-04-04      clothing
#  ...                 ...           ...             ...           ...
#  1435  tshirt kleid kurz          high        5-4-Q-02   accessoires
#  1436  tshirt kleid kurz         entry     2-1-C-04-01      clothing
#  1437  tshirt kleid kurz           low     2-1-C-04-01      clothing
#  1438  tshirt kleid kurz           low     3-1-E-02-02        beauty
#  1439  tshirt kleid kurz           low           2-1-D      clothing
#
#           silhouette            brand        color upper_material    pattern  \
#  1360          dress          b.young         grün      undefined  undefined
#  1361    t_shirt_top  Mother of Pearl        weiss      undefined      print
#  1362    t_shirt_top            NA-KD        weiss      undefined  Fotoprint
#  1363          dress            RIANI        weiss      undefined  undefined
#  1364          dress  Nike Sportswear        weiss      undefined  unifarben
#  ...             ...              ...          ...            ...        ...
#  1435       headgear  Armani Exchange        weiss      undefined      print
#  1436          dress        Noisy May      schwarz      undefined  unifarben
#  1437          dress        Simply Be      schwarz      undefined  unifarben
#  1438  face_cosmetic    L'Oréal Paris  sonderfarbe      undefined  undefined
#  1439          dress             mbyM      schwarz      undefined  undefined
#
#        label
#  1360      0
#  1361      0
#  1362      1
#  1363      0
#  1364      0
#  ...     ...
#  1435      1
#  1436      0
#  1437      0
#  1438      1
#  1439      0
#
#  [80 rows x 10 columns],
#  'wanderschuhe lowa kinder':                          query price_cluster commodity_group product_group  \
#  1760  wanderschuhe lowa kinder        medium      4-3-A-01-2          shoe
#  1761  wanderschuhe lowa kinder        medium      4-3-A-01-4          shoe
#  1762  wanderschuhe lowa kinder        medium      4-3-C-01-2          shoe
#  1763  wanderschuhe lowa kinder        medium      4-3-A-01-1          shoe
#  1764  wanderschuhe lowa kinder        medium      4-3-A-01-1          shoe
#  ...                        ...           ...             ...           ...
#  1835  wanderschuhe lowa kinder        medium      4-3-C-01-2          shoe
#  1836  wanderschuhe lowa kinder        medium      4-3-A-01-1          shoe
#  1837  wanderschuhe lowa kinder        medium      4-3-A-01-1          shoe
#  1838  wanderschuhe lowa kinder        medium      4-3-A-01-2          shoe
#  1839  wanderschuhe lowa kinder          high      4-3-A-01-2          shoe
#
#       silhouette          brand   color      upper_material    pattern  label
#  1760      boots            CMP    lila    Leder und Textil  undefined      0
#  1761   low_shoe      Kastinger    blau  Lederimitat/Textil  undefined      0
#  1762      boots        Salomon    lila   Kunststoff/Textil      print      0
#  1763   low_shoe        Salomon    gelb   Kunststoff/Textil      print      0
#  1764   low_shoe        Salomon    blau    Textil/Synthetik  unifarben      0
#  ...         ...            ...     ...                 ...        ...    ...
#  1835      boots           Lowa  petrol   Kunststoff/Textil      print      0
#  1836   low_shoe  Jack Wolfskin    lila   Kunststoff/Textil  undefined      0
#  1837   low_shoe           Lowa    grau  Lederimitat/Textil      print      0
#  1838      boots           Lowa   beige    Leder und Textil  undefined      0
#  1839      boots           Lowa  türkis   Kunststoff/Textil      print      0
#
#  [80 rows x 10 columns]}

# %%
#Just a tabel to see the predicted and true label.
y_pred = clf.predict(X_test)
prediction_df = pd.DataFrame(data={'query':X_test["query"], 'new_predictions': y_pred,'truth':y_test})
prediction_df
# Out:
#       query  new_predictions  truth
# 801     8.0                0      0
# 1059   22.0                0      0
# 1237    0.0                0      0
# 270    12.0                1      1
# 1720    2.0                0      0
# ...     ...              ...    ...
# 625     5.0                0      0
# 595     5.0                1      1
# 887     9.0                0      0
# 1623   14.0                1      1
# 2080   13.0                0      0
#
# [432 rows x 3 columns]

# %%
#Here we can see the feature importance of the model.
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(clf.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
importances
# Out:
#           feature  importance
# 0           query       0.314
# 3      silhouette       0.270
# 4           brand       0.123
# 1   price_cluster       0.082
# 2   product_group       0.070
# 6  upper_material       0.054
# 7         pattern       0.050
# 5           color       0.037

# %%
#Plot of faeture importance.
# %matplotlib inline
importances.plot(x='feature', kind="bar")
plt.xticks(rotation=30)
plt.title(" Feature Importance")
plt.ylabel('message click', fontsize=12)
plt.xlabel('', fontsize=12)
plt.xticks(fontsize=10,rotation=90)
plt.yticks(fontsize=12)
# Out:
# (array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#this plot shows the optimal depth of the tree. 
# List of values to try for max_depth:
max_depth_range = list(range(1, 20))# List to store the average RMSE for each value of max_depth:
accuracy = []

for depth in max_depth_range:
    clf = DecisionTreeClassifier(max_depth = depth, random_state = 0)
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    accuracy.append(score)
    
plt.plot(max_depth_range, accuracy,color='g')
plt.xlabel('max_depth_range')
plt.ylabel('accuracy')
plt.title('Tuning the Depth of a Tree')
plt.show()

# %%
#Confusion matrix.
from sklearn.metrics import classification_report, confusion_matrix#for visualizing tree cm = confusion_matrix(y_train, y_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(data=cm,linewidths=.5, annot=True,square = True,  cmap = 'Blues',fmt='g')
plt.ylabel('Predicted label')
plt.xlabel('Actual label')
# Out:
# Text(0.5, 48.29999999999998, 'Actual label')

# %%
# let run a gridsearch to see which parameters are optimal for the model.
from sklearn.model_selection import GridSearchCV
param_dic = {"criterion": ['gini','entropy'],
             "max_depth":range(1,20),
             "min_samples_split":range(1,20),
             "min_samples_leaf":range(1,10)}

# %%
#Textual reperesntation of tree.
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= 10.50
# |   |--- feature_2 <= 1.50
# |   |   |--- class: 1
# |   |--- feature_2 >  1.50
# |   |   |--- feature_2 <= 7.50
# |   |   |   |--- feature_3 <= 35.50
# |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |--- feature_2 <= 5.00
# |   |   |   |   |   |   |--- feature_4 <= 461.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  461.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  5.00
# |   |   |   |   |   |   |--- feature_4 <= 72.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  72.00
# |   |   |   |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |--- feature_4 <= 26.50
# |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |--- feature_7 <= 12.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  12.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_4 >  26.50
# |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 24.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  24.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 77.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  77.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |--- feature_4 <= 394.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  394.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  35.50
# |   |   |   |   |--- feature_3 <= 37.50
# |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |--- feature_4 <= 132.50
# |   |   |   |   |   |   |   |--- feature_4 <= 95.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  95.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  132.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  37.50
# |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |--- feature_0 <= 9.00
# |   |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  1.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 16.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  16.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 172.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  172.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  9.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |--- feature_0 <= 1.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  1.00
# |   |   |   |   |   |   |   |--- feature_4 <= 469.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  469.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 472.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  472.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_2 >  7.50
# |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |--- feature_5 <= 10.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_5 >  10.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |--- class: 1
# |--- feature_0 >  10.50
# |   |--- feature_6 <= 4.50
# |   |   |--- feature_6 <= 3.50
# |   |   |   |--- feature_1 <= 2.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  2.00
# |   |   |   |   |--- class: 0
# |   |   |--- feature_6 >  3.50
# |   |   |   |--- class: 1
# |   |--- feature_6 >  4.50
# |   |   |--- feature_4 <= 24.50
# |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |--- feature_3 <= 17.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  17.00
# |   |   |   |   |   |   |--- feature_5 <= 2.00
# |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  2.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |--- feature_4 <= 3.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_4 >  3.00
# |   |   |   |   |   |--- feature_3 <= 37.50
# |   |   |   |   |   |   |--- feature_5 <= 5.00
# |   |   |   |   |   |   |   |--- feature_3 <= 8.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  8.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 20.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  20.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  5.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  37.50
# |   |   |   |   |   |   |--- feature_4 <= 10.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  10.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_4 >  24.50
# |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |--- feature_3 <= 23.50
# |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |--- feature_3 <= 16.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 15.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  15.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  16.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 310.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  310.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- feature_3 >  23.50
# |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |--- feature_3 <= 33.50
# |   |   |   |   |   |   |   |--- feature_4 <= 366.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  366.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  33.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |--- feature_6 <= 21.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_6 >  21.50
# |   |   |   |   |   |   |   |--- feature_4 <= 305.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 32.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  32.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 262.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  262.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_4 >  305.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |--- feature_3 <= 28.50
# |   |   |   |   |   |--- feature_3 <= 8.00
# |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 446.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_4 >  446.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 19.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  19.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 437.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  437.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  8.00
# |   |   |   |   |   |   |--- feature_0 <= 20.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  20.50
# |   |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 135.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  135.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 239.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  239.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  28.50
# |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |--- feature_4 <= 278.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 19.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  19.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  278.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 322.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  322.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 406.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  406.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |   |   |   |--- feature_2 <= 5.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 37.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  37.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  5.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 34.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  34.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 480.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 309.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  309.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 437.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  437.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  480.00
# |   |   |   |   |   |   |   |   |   |--- class: 0

# %% [markdown]
# With random forest I reached a better Acuuracy 0.91

# %%
#Lets run the model with Random forest.
X_train, X_test, y_train, y_test = train_test_split(x_features, y_label, test_size=0.3, random_state=1) # 70% training and 30% test
rfc = RandomForestClassifier(n_estimators=40,random_state=0)
# fit the model
rfc.fit(X_train, y_train)
# Predict the Test set results
y_pred = rfc.predict(X_test)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.9151
